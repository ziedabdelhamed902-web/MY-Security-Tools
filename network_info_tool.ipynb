# %% [markdown]
# <a href="https://colab.research.google.com/github/ziedabdelhamed902-web/MY-Security-Tools/blob/main/network_info_tool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import socket

print("=== My Second Securrity Tool ===")

hostname = socket.gethostname()
internal_ip = socket.gethostbyname(hostname)

print(f"[+] your Device name: {hostname}")
print(f"[+] your Internal Ip: {internal_ip}")

print("-" * 30)

target_wepsite = "8.8.8.8"
print(f"Checking internet connection to {target_wepsite}....")

response = os.system(f"ping -c 1 {target_wepsite}" if os.name != 'nt' else f"ping -n 1 {target_website}")

if response == 0:
  print("[*] Internet Status: ONLINE and Connected!")
else:
  print("[-]Internet Status:OFFLINE or Blocked!")
# Out:
# === My Second Securrity Tool ===
# [+] your Device name: d55f1fbfa9d3
# [+] your Internal Ip: 172.28.0.12
# ------------------------------
# Checking internet connection to 8.8.8.8....
# [-]Internet Status:OFFLINE or Blocked!
