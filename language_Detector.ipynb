# %% [markdown]
# <a href="https://colab.research.google.com/github/ziedabdelhamed902-web/MY-Security-Tools/blob/main/language_Detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langdetect
from langdetect import detect
text = "En algún momento, todo se desvanecerá, así que debemos seguir adelante ahora"
result = detect(text)
print(f"The language is: {result}")
# Out:
# ...
# The language is: es
