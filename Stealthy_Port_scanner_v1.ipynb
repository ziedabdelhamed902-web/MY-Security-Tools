# %% [markdown]
# <a href="https://colab.research.google.com/github/ziedabdelhamed902-web/MY-Security-Tools/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import socket
import time
terget = "8.8.8.8"
for port in range(440, 445):
  s = socket.socket(socket.AF_INET,socket.SOCK_STREAM)
  s.settimeout(1)
  result = s.connect_ex((target, port))
  if result == 0:
    print(f"port {port} is OPEN! ")
  else:
      print(f"port {port} is CLOSED. ")

      s.close()
      print("Waiting for 2  seconds to stay hidden")
      time.sleep(2)
# Out:
# port 440 is CLOSED.
# Waiting for 2  seconds to stay hidden
# port 441 is CLOSED.
# Waiting for 2  seconds to stay hidden
# port 442 is CLOSED.
# Waiting for 2  seconds to stay hidden
# port 443 is OPEN!
# port 444 is CLOSED.
# Waiting for 2  seconds to stay hidden
