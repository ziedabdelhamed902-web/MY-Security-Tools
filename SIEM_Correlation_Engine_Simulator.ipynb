# %% [markdown]
# <a href="https://colab.research.google.com/github/ziedabdelhamed902-web/MY-Security-Tools/blob/main/SIEM_Correlation_Engine_Simulator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
events = [
    {"user": "billing_mgr", "action": "failed_login"},
    {"user": "billing_mgr", "action": "failed_login"},
    {"user": "billing_mgr", "action": "failed_login"},
    {"user": "billing_mgr", "action": "successful_login"},
    {"user": "billing_mgr", "action": "privilega_escalation"}
]
failed_counter = 0
stage_login_success = False
print("SIEM correlation Engine Active. Scanning events stream...\n")
for event in events:
    user = event["user"]
    action = event["action"]
if action == "failed_login":
    failed_counter += 1
elif action == "successful_login" and failed_counter >= 3:
     stage_login_success = True
elif action == "privilege_escalation" and stage_login_success:
      print(f"CRITCAL SIEM ALARM: Account takeover Chain Detected for [{user}]!")
      print("Chain: Multiple failed Logins -> Sudden Success -> Dircet privilege Change.")
      print("Status: Compromised account isolated.")
# Out:
# SIEM correlation Engine Active. Scanning events stream...
