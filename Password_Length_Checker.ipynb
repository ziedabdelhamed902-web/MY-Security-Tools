# %% [markdown]
# <a href="https://colab.research.google.com/github/ziedabdelhamed902-web/MY-Security-Tools/blob/main/Password_Length_Checker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
user_password = "ziad6737"
password_length = len(user_password)
if password_length < 8:
     print("Status: Weak password. Needs more characters.")
else:
  print("Status: Strong length. password accepted.")
# Out:
# Status: Strong length. password accepted.
